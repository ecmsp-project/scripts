# %%
import uuid
import random
from datetime import datetime

# %%
with open("sample_data.sql", "w", encoding="utf-8") as file:
        pass

# %%
category_names = [
    "Clothes",
    "Electronics",
    "Books",
    "Beauty",
    "Sports",
    "Toys",
    "Food"
]

# category_dict: dict[str, uuid.UUID | None] = {category_name: None for category_name in category_names}
category_dict = {}

# %%
def generate_categories(file, category_names):
    text = f'INSERT INTO categories(id, parent_category_id, name)\n'
    file.write(text)

    text = f'VALUES\n'
    file.write(text)

    n = len(category_names)
    for category_name in category_names[:n-1]:
        category_id = uuid.uuid4()
        category_dict[category_name] = category_id

        text = f"\t('{category_id}', NULL, '{category_name}'),\n"
        file.write(text)
    #
    
    category_name = category_names[-1]
    category_id = uuid.uuid4()
    category_dict[category_name] = category_id
    text = f"\t('{category_id}', NULL, '{category_name}');\n\n"
    file.write(text)
#

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
    generate_categories(file, category_names)

# %%
category_names_with_parent = {
    "Man": category_dict["Clothes"],
    "Woman": category_dict["Clothes"],
    
    "Computers": category_dict["Electronics"],
    "Mobile Phones": category_dict["Electronics"],
    "TV and accessories": category_dict["Electronics"],
    "Home appliances":  category_dict["Electronics"],
    
    "Hair dryers": category_dict["Beauty"],
    "Oral hygiene": category_dict["Beauty"],
    "Face hygiene": category_dict["Beauty"],
    "Health": category_dict["Beauty"],
    "Relax and massage": category_dict["Beauty"],

    "Team Sports": category_dict["Sports"],
    "Individual Sports": category_dict["Sports"],
    "Fitness & Exercise": category_dict["Sports"],
    "Outdoor & Adventure": category_dict["Sports"],

    "Educational Toys": category_dict["Toys"],
    "Electronics & Robotic Toys": category_dict["Toys"],
    "Game & Puzzles": category_dict["Toys"],
    "Building & Construction Toys": category_dict["Toys"]
}

# %%
def generate_categories_with_parent_id(file, category_names_with_parent):
    text = f'INSERT INTO categories(id, parent_category_id, name)\n'
    file.write(text)

    text = f'VALUES\n'
    file.write(text)

    n = len(category_names_with_parent)
    categories = list(category_names_with_parent.items())

    for category_name, category_parent_id in categories[:n-1]:
        category_id = uuid.uuid4()
        category_dict[category_name] = category_id

        text = f"\t('{category_id}', '{category_parent_id}', '{category_name}'),\n"
        file.write(text)
    #
    
    category_name, category_parent_id = categories[-1]
    category_id = uuid.uuid4()
    category_dict[category_name] = category_id
    text = f"\t('{category_id}', '{category_parent_id}', '{category_name}');\n\n"
    file.write(text)
#

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
    generate_categories_with_parent_id(file, category_names_with_parent)

# %%
category_names_with_parent2 = {
    "T-shirts": category_dict["Man"],
    "Jeans": category_dict["Man"],
    "Jackets": category_dict["Man"],
    "Sweatshirts": category_dict["Man"],
    
    "Accessories": category_dict["Man"],

    "Dresses": category_dict["Woman"],
    "Skirts": category_dict["Woman"],

    "Dishwashers":  category_dict["Home appliances"],
    "Washing machines":  category_dict["Home appliances"],
    "Clothes dryer": category_dict["Home appliances"],

}

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
    generate_categories_with_parent_id(file, category_names_with_parent2)

# %%
class Product:
    def __init__(self, id, category_id, name, link, approximate_price = 30.00, delivery_price = 15.00, description = "", info = "NULL"):
        self.id = id
        self.name = name
        self.category_id = category_id
        self.approximate_price = approximate_price
        self.delivery_price = delivery_price
        self.description = description
        self.link = link
        self.info = info
        self.variants: list[Variant] = []
    #

    def add_variant(self, variant):
        self.variants.append(variant)

    def set_variants(self, variants):
        self.variants = variants
#

class Variant:
    def __init__(self, id, product_id, price, description = "", additional_properties = "NULL"):
        self.id = id
        self.product_id = product_id
        self.price = price
        self.description = description

        self.stock_quantity = random.randint(1, 50)
        self.additional_properties = additional_properties
    #

product_dict: dict[uuid.UUID, Product] = {}

# %%
products = [    
    Product(
        uuid.uuid4(),
        category_dict["Jackets"],
        "The North Face QUEST - Kurtka przeciwdeszczowa",
        "https://www.zalando.pl/the-north-face-quest-kurtka-hardshell-th342f01b-q11.html",
        399.00,
        description = "A versatile outdoor garment designed for hiking, trekking, and alpinism. Made from Polartec fabric, it offers high breathability while remaining fully windproof and waterproof, ensuring reliable protection and comfort in changing mountain conditions."
    ),

    Product(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Bosch WAN2415GPL Washing Machine",
        "https://allegro.pl/oferta/pralka-bosch-wan2415gpl-17760677474",
        403.91,
        description = "The Bosch Serie 6 WGG154ZSPL washing machine offers a 10 kg load capacity, 1400 RPM spin speed, and 14 versatile programs. Its 70 L drum ensures perfectly clean laundry with minimal water usage, even for smaller loads, thanks to the ActiveWater Plus system. Energy efficient and quiet, it features an advanced side panel design that reduces vibrations and noise during spinning. Powered by the EcoSilence Drive motor, it also comes with the option of a free 10 year extended warranty when registered online."
    ),

    Product(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Bosch Series 6 WGG154ZSPL Washing Machine - 10 kg, 1400 RPM, steam, energy-efficient",
        "https://allegro.pl/oferta/pralka-bosch-seria-6-wgg154zspl-10-kg1400-obr-para-oszczedna-17871517209",
        645.76,
        description = "The Bosch Serie 6 WGG154ZSPL washing machine offers a 10 kg load capacity, 1400 RPM spin speed, and 14 wash programs. The large 70 L VarioDrum ensures thorough cleaning even with smaller loads, supported by the water-saving ActiveWater Plus system. It operates in top energy class A and features a side-panel design that reduces noise and vibration during spinning. The EcoSilence Drive motor provides quiet, reliable performance and can be registered online for a free 10-year warranty. The Iron Assist steam function helps reduce wrinkles by up to 50 percent, making clothes easier to iron."
    ),

    Product(
        uuid.uuid4(),
        category_dict["Sweatshirts"],
        "U.S. Polo Assn. - Bluza",
        'https://www.zalando.pl/us-polo-assn-bluza-dark-sapphire-us222s05n-k11.html',
        175.00,
        description = "A casual mens sweatshirt from U.S. Polo Assn., combining a clean design with everyday comfort. Made from soft, durable fabric, it offers a relaxed fit suitable for regular wear. Ideal for layering and versatile styling."
    ),

    # 4
    Product(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Bosch WGB2440EPL Washing Machine - 1400 RPM, 9 kg, 69 dB, White",
        'https://allegro.pl/oferta/pralka-bosch-wgb2440epl-1400-obr-min-9-kg-69-db-biala-17626421705',
        1044.74,
        description = "The Bosch Serie 6 WGG154ZSPL washing machine offers a 10 kg load capacity, 1400 RPM spin speed, and 14 wash programs. The 70 L VarioDrum ensures efficient and gentle washing, while ActiveWater Plus optimizes water usage even for small loads. The machine operates in energy class A and features a side-panel design that reduces noise and vibration. The EcoSilence Drive motor provides quiet, durable performance and can be registered online for a free 10-year warranty. The Iron Assist steam program reduces wrinkles by up to 50 percent, making ironing easier and refreshing shirts or garments in about 20 minutes."
    ),

    # 5
    Product(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Whirlpool Industrial Washing Machine AWG1114SD",
        'https://allegro.pl/oferta/whirlpool-pralka-przemyslowa-awg1114sd-14764208353',
        1139.05,
        description = "The WHIRLPOOL AWG1114SD is an industrial front-loading washing machine designed for heavy-duty use. It offers an 11 kg load capacity with 14 versatile programs to handle a wide range of laundry needs. The machine features a clear display and electro-mechanical controls for easy operation. Built for efficiency, it holds an energy rating of Class A and operates quietly, with a noise level of 76–80 dB during spinning. Its robust design, durable materials, and reliable performance make it ideal for commercial or industrial laundry environments."
    ),

    # 6
    Product(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Whirlpool FFB9258SVPL Washing Machine – 9 kg, 1200 RPM, 14 programs, Inverter motor, FreshCare+",
        'https://allegro.pl/oferta/pralka-whirlpool-ffb9258svpl-9kg-1200obr-14programow-inwerter-freshcare-17290855885',
        335.42,
        description = "The Whirlpool FFB9258SVPL is a freestanding front-loading washing machine designed for convenient and efficient home laundry. With a 9 kg drum and 1200 RPM spin speed, it handles everyday laundry with ease. The machine offers 14 versatile programs to suit different fabric types and soil levels. Key features include FreshCare+, which keeps clothes fresh for hours after the cycle ends by gently massaging fabrics with steam and drum movements, and Steam Refresh, which removes odors and smooths wrinkles in just 20 minutes. The Sense Inverter motor ensures quiet, energy-efficient, and long-lasting performance. Additional features include foam and imbalance control, adjustable spin speed, end-of-cycle indicator, and a child lock for safety. This washing machine combines advanced technology with practical convenience for everyday use."
    ),

    # 7
    Product(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "U.S. Polo Assn. ARJUN - T-shirt basic",
        'https://www.zalando.pl/us-polo-assn-t-shirt-basic-dark-sapphire-us222o00s-k13.html',
        21.21,
        description = "Basic dark sapphire T-shirt by U.S. Polo Assn., comfortable fit and casual style."
    )
]

products_indices = {idx: product for idx, product in enumerate(products)}
product_dict = {product.id: product for product in products}

# %%
variants_dict = {
    0: [
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/0191884300c544d48b3687e4b2d7f81d/ca57701fb7a84baa9c5ad82bce0dd4ed.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/0191884300c544d48b3687e4b2d7f81d/ca57701fb7a84baa9c5ad82bce0dd4ed.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/0191884300c544d48b3687e4b2d7f81d/ca57701fb7a84baa9c5ad82bce0dd4ed.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/68cd85274d6048b8a8c0b62ecf375583/58d90715482048ecbc6491c97d6807d4.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/68cd85274d6048b8a8c0b62ecf375583/58d90715482048ecbc6491c97d6807d4.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/68cd85274d6048b8a8c0b62ecf375583/58d90715482048ecbc6491c97d6807d4.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/bc6dbbf7f7674b9c8a39aa67f5ba8cfb/44db2655e7f24e81b5de7df334a2f8ea.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/bc6dbbf7f7674b9c8a39aa67f5ba8cfb/44db2655e7f24e81b5de7df334a2f8ea.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[0].id,
            products_indices[0].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/bc6dbbf7f7674b9c8a39aa67f5ba8cfb/44db2655e7f24e81b5de7df334a2f8ea.jpg?imwidth=1800"
        )
    ],

    1: [
        Variant(
            uuid.uuid4(),
            products_indices[1].id,
            products_indices[1].approximate_price
        )
    ],

    2: [
        Variant(
            uuid.uuid4(),
            products_indices[2].id,
            products_indices[2].approximate_price
        )
    ],

    3: [
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/ff1bceeff6c24cce84a1ef2bbd84558f/d5f7ade366284fa38df75e299f068e1c.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/ff1bceeff6c24cce84a1ef2bbd84558f/d5f7ade366284fa38df75e299f068e1c.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/ff1bceeff6c24cce84a1ef2bbd84558f/d5f7ade366284fa38df75e299f068e1c.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/968e57ce51d94852b565cc139066659e/08c64c6c114647ce9c11956d4d93c550.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/968e57ce51d94852b565cc139066659e/08c64c6c114647ce9c11956d4d93c550.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/968e57ce51d94852b565cc139066659e/08c64c6c114647ce9c11956d4d93c550.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/08aaca16bdb34831a74e6bdfee0a494f/c509169c3b9c4b839a6d258cd0b60556.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/08aaca16bdb34831a74e6bdfee0a494f/c509169c3b9c4b839a6d258cd0b60556.jpg?imwidth=1800"
        ),
        Variant(
            uuid.uuid4(),
            products_indices[3].id,
            products_indices[3].approximate_price
            # "https://img01.ztat.net/article/spp-media-p1/08aaca16bdb34831a74e6bdfee0a494f/c509169c3b9c4b839a6d258cd0b60556.jpg?imwidth=1800"
        )
    ],

    4: [
        Variant(
            uuid.uuid4(),
            products_indices[4].id,
            products_indices[4].approximate_price
        )
    ],

    5: [
        Variant(
            uuid.uuid4(),
            products_indices[5].id,
            products_indices[5].approximate_price
        )
    ],

    6: [
        Variant(
            uuid.uuid4(),
            products_indices[6].id,
            products_indices[6].approximate_price
        )
    ],

    7: [
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        ),
        Variant(
            uuid.uuid4(),
            products_indices[7].id,
            products_indices[7].approximate_price
        )
    ]
}

# %%
def generate_products(file):
    text = f'INSERT INTO products(id, category_id, name, approximate_price, delivery_price, description, info)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    n = len(products)
    for product in products[:n-1]:
        text = f"\t('{product.id}', '{product.category_id}', '{product.name}', {product.approximate_price}, {product.delivery_price}, '{product.description}', {product.info}),\n"
        file.write(text)
    #

    product = products[-1]    
    text = f"\t('{product.id}', '{product.category_id}', '{product.name}', {product.approximate_price}, {product.delivery_price}, '{product.description}', {product.info});\n\n"
    file.write(text)
#

# %%
def generate_variants(file):
    text = f'INSERT INTO variants(id, product_id, price, stock_quantity, additional_properties, description, created_at, updated_at)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    variants_list = sum(variants_dict.values(), [])
    n = len(variants_list)
    for variant in variants_list[:n-1]:
        text = f"\t('{variant.id}', '{variant.product_id}', {variant.price}, {variant.stock_quantity}, {variant.additional_properties}, '{product_dict[variant.product_id].description}', '{datetime.now()}', '{datetime.now()}'),\n"
        file.write(text)
    #

    variant = variants_list[-1]
    text = f"\t('{variant.id}', '{variant.product_id}', {variant.price}, {variant.stock_quantity}, {variant.additional_properties}, '{product_dict[variant.product_id].description}', '{datetime.now()}', '{datetime.now()}');\n\n"
    file.write(text)
#

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
    generate_products(file)
    generate_variants(file)

# %%
class VariantImage:
    def __init__(self, id, variant_id, url, position, is_main = "FALSE"):
        self.id = id
        self.variant_id = variant_id
        self.url = url
        self.position = position
        self.is_main = is_main
    #

# %%
variants_images = [

    VariantImage(
        uuid.uuid4(),
        variants_dict[0][0].id,
        "https://img01.ztat.net/article/spp-media-p1/e7d5535687874a518997522421231596/083a79b5507d44b0ba37460bf7169961.jpg?imwidth=1800",
        1,
        "TRUE",
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][0].id,
        "https://img01.ztat.net/article/spp-media-p1/1f4a7b35647145aa83949357c38ebbf7/184e264ef0b848928b4fc45d92604e13.jpg?imwidth=1800",
        2,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][0].id,
        "https://img01.ztat.net/article/spp-media-p1/c61704b0794144afac449007b6094966/12449b06c0d04e9583adcc9cfe9d7b34.jpg?imwidth=1800",
        3,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][0].id,
        "https://img01.ztat.net/article/spp-media-p1/dc190f0d0a57448699e86c73881391fe/4b1d1c00cc8c4d4183c5b010bf2413ec.jpg?imwidth=1800",
        4,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][0].id,
        "https://img01.ztat.net/article/spp-media-p1/64f9e64b72fe4ffbabaa620816436caa/415c23d7a9b748c694e30b61a4dc1568.jpg?imwidth=1800",
        5,
    ),


# ---------------------
# ---------------------
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][1].id,
        "https://img01.ztat.net/article/spp-media-p1/e7d5535687874a518997522421231596/083a79b5507d44b0ba37460bf7169961.jpg?imwidth=1800",
        1,
        "TRUE",
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0

    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][7].id,
        "https://img01.ztat.net/article/spp-media-p1/dc190f0d0a57448699e86c73881391fe/4b1d1c00cc8c4d4183c5b010bf2413ec.jpg?imwidth=1800",
        4,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][7].id,
        "https://img01.ztat.net/article/spp-media-p1/64f9e64b72fe4ffbabaa620816436caa/415c23d7a9b748c694e30b61a4dc1568.jpg?imwidth=1800",
        5,
    ),


    VariantImage(
        uuid.uuid4(),
        variants_dict[0][8].id,
        "https://img01.ztat.net/article/spp-media-p1/e7d5535687874a518997522421231596/083a79b5507d44b0ba37460bf7169961.jpg?imwidth=1800",
        1,
        "TRUE",
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][8].id,
        "https://img01.ztat.net/article/spp-media-p1/1f4a7b35647145aa83949357c38ebbf7/184e264ef0b848928b4fc45d92604e13.jpg?imwidth=1800",
        2,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][8].id,
        "https://img01.ztat.net/article/spp-media-p1/c61704b0794144afac449007b6094966/12449b06c0d04e9583adcc9cfe9d7b34.jpg?imwidth=1800",
        3,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][8].id,
        "https://img01.ztat.net/article/spp-media-p1/dc190f0d0a57448699e86c73881391fe/4b1d1c00cc8c4d4183c5b010bf2413ec.jpg?imwidth=1800",
        4,
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[0][8].id,
        "https://img01.ztat.net/article/spp-media-p1/64f9e64b72fe4ffbabaa620816436caa/415c23d7a9b748c694e30b61a4dc1568.jpg?imwidth=1800",
        5,
    ),
# ---------------------

    VariantImage(
        uuid.uuid4(),
        variants_dict[1][0].id,
        "https://a.allegroimg.com/s1024/11b31b/652a3e3b4a89acedab407e1ceac0/Pralka-Bosch-WAN2415GPL",
        1,
        "TRUE"
    ),

# ---------------------

    VariantImage(
        uuid.uuid4(),
        variants_dict[2][0].id,
        "https://a.allegroimg.com/s1024/11bd3a/0c6f3b9f4620aa3b8a0de5224e00/Pralka-Bosch-Seria-6-WGG154ZSPL-10-kg1400-obr-para-oszczedna-Maksymalny-wsad-10-kg",
        1,
        "TRUE"
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[2][0].id,
        "https://a.allegroimg.com/s720/11cf65/9a8653b8494bb5c85e63deb0cbb1/Pralka-Bosch-Seria-6-WGG154ZSPL-10-kg1400-obr-para-oszczedna-Sposob-zaladunku-od-frontu",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[2][0].id,
        "https://a.allegroimg.com/s720/11fa51/7598e3f7415dae3b150ba2b02edc/Pralka-Bosch-Seria-6-WGG154ZSPL-10-kg1400-obr-para-oszczedna-Wysokosc-produktu-84-5-cm",
        3
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[2][0].id,
        "https://a.allegroimg.com/s720/117b70/661f725b40219665976998c3130e/Pralka-Bosch-Seria-6-WGG154ZSPL-10-kg1400-obr-para-oszczedna-Model-WGG154ZSPL",
        4
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[2][0].id,
        "https://a.allegroimg.com/s720/11a284/e12ec5de4b39a0749ad7643e3146/Pralka-Bosch-Seria-6-WGG154ZSPL-10-kg1400-obr-para-oszczedna-Marka-Bosch",
        5
    ),

# ---------------------

    VariantImage(
        uuid.uuid4(),
        variants_dict[4][0].id,
        "https://a.allegroimg.com/s720/1150f5/6a6b06684e09829bc365346585a8/Pralka-Bosch-WGB2440EPL-1400-obr-min-9-kg-69-dB-Biala",
        1,
        "TRUE"
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[4][0].id,
        "https://a.allegroimg.com/s720/116f7e/d614e4d64adc9323cf0d4a6c7a5a/Pralka-Bosch-WGB2440EPL-1400-obr-min-9-kg-69-dB-Biala-Kod-producenta-WGB2440EPL",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[4][0].id,
        "https://a.allegroimg.com/s720/112759/ad9dfa5e4d38879d55a90a9b7442/Pralka-Bosch-WGB2440EPL-1400-obr-min-9-kg-69-dB-Biala-Marka-Bosch",
        3
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[4][0].id,
        "https://a.allegroimg.com/s720/112759/ad9dfa5e4d38879d55a90a9b7442/Pralka-Bosch-WGB2440EPL-1400-obr-min-9-kg-69-dB-Biala-Marka-Bosch",
        4
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[4][0].id,
        "https://a.allegroimg.com/s720/1125bd/113fe99440a09336d763cd273cf6/Pralka-Bosch-WGB2440EPL-1400-obr-min-9-kg-69-dB-Biala-Kolor-dominujacy-bialy",
        5
    ),

# ---------------------

    VariantImage(
        uuid.uuid4(),
        variants_dict[5][0].id,
        "https://a.allegroimg.com/s720/11aefa/7f41462e4261902c9b4c17778882/WHIRLPOOL-Pralka-przemyslowa-AWG1114SD",
        1,
        "TRUE"
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[5][0].id,
        "https://a.allegroimg.com/s720/1113b9/5eb4a698453cb29c69fcb90ae4a7/WHIRLPOOL-Pralka-przemyslowa-AWG1114SD-Kod-producenta-869991655660",
        2
    ),
    
# ---------------------

    VariantImage(
        uuid.uuid4(),
        variants_dict[6][0].id,
        "https://a.allegroimg.com/s720/11f7aa/d737f35d48019295dc61d6430375/Pralka-WHIRLPOOL-FFB9258SVPL-9kg-1200obr-14programow-inwerter-FreshCare",
        1,
        "TRUE"
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[6][0].id,
        "https://a.allegroimg.com/s720/11d0be/e1b0896e419897f920c50e76861c/Pralka-WHIRLPOOL-FFB9258SVPL-9kg-1200obr-14programow-inwerter-FreshCare-Marka-Whirlpool",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[6][0].id,
        "https://a.allegroimg.com/s720/1176c9/1a9894d648738a674dd703a9b102/Pralka-WHIRLPOOL-FFB9258SVPL-9kg-1200obr-14programow-inwerter-FreshCare-Kolor-dominujacy-bialy",
        3
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[6][0].id,
        "https://a.allegroimg.com/s720/1144cb/a29bcfae4ac6a1a1b4a07e9936c1/Pralka-WHIRLPOOL-FFB9258SVPL-9kg-1200obr-14programow-inwerter-FreshCare-Stan-opakowania-oryginalne",
        4
    ),

    VariantImage(
        uuid.uuid4(),
        variants_dict[7][0].id,
        "https://img01.ztat.net/article/spp-media-p1/216b9e974c43487d9c5863dcff45f2b0/592fdc01317647a9a47072654e355dbc.jpg?imwidth=1800",
        1
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[7][0].id,
        "https://img01.ztat.net/article/spp-media-p1/e4ff9126c14844248ed886d968298c61/ac6d009ad2a7484b8173b2e62603a9bf.jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[7][0].id,
        "https://img01.ztat.net/article/spp-media-p1/b9ba234c625947c7a044612c887155b3/d15cd33de1914600b1019db85e09294d.jpg?imwidth=1800",
        3
    ),

    VariantImage(
        uuid.uuid4(),
        variants_dict[7][1].id,
        "https://img01.ztat.net/article/spp-media-p1/216b9e974c43487d9c5863dcff45f2b0/592fdc01317647a9a47072654e355dbc.jpg?imwidth=1800",
        1
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[7][1].id,
        "https://img01.ztat.net/article/spp-media-p1/e4ff9126c14844248ed886d968298c61/ac6d009ad2a7484b8173b2e62603a9bf.jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[7
jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][5].id,
        "https://img01.ztat.net/article/spp-media-p1/40dc24fa4f014d06a91ebfb57843a2ab/4f765203e6054e188db98db9c7ed19d4.jpg?imwidth=1800",
        3
    ),

    VariantImage(
        uuid.uuid4(),
        variants_dict[3][6].id,
        "https://img01.ztat.net/article/spp-media-p1/eee9465b4fd747e0b03d2c0520e2918b/0ef1480409764c0085d0f13de68976fd.jpg?imwidth=1800",
        1
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][6].id,
        "https://img01.ztat.net/article/spp-media-p1/8c60e6ba81644d228135428e421e7c5f/4b53e047209d4076a1346373bbccd925.jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][6].id,
        "https://img01.ztat.net/article/spp-media-p1/e3d46ff273a34a19a49e6443115b8140/91b9d8a903784ca5a703cb22801b1fe9.jpg?imwidth=1800",
        3
    ),

    VariantImage(
        uuid.uuid4(),
        variants_dict[3][7].id,
        "https://img01.ztat.net/article/spp-media-p1/eee9465b4fd747e0b03d2c0520e2918b/0ef1480409764c0085d0f13de68976fd.jpg?imwidth=1800",
        1
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][7].id,
        "https://img01.ztat.net/article/spp-media-p1/8c60e6ba81644d228135428e421e7c5f/4b53e047209d4076a1346373bbccd925.jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][7].id,
        "https://img01.ztat.net/article/spp-media-p1/e3d46ff273a34a19a49e6443115b8140/91b9d8a903784ca5a703cb22801b1fe9.jpg?imwidth=1800",
        3
    ),

    VariantImage(
        uuid.uuid4(),
        variants_dict[3][8].id,
        "https://img01.ztat.net/article/spp-media-p1/eee9465b4fd747e0b03d2c0520e2918b/0ef1480409764c0085d0f13de68976fd.jpg?imwidth=1800",
        1
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][8].id,
        "https://img01.ztat.net/article/spp-media-p1/8c60e6ba81644d228135428e421e7c5f/4b53e047209d4076a1346373bbccd925.jpg?imwidth=1800",
        2
    ),
    VariantImage(
        uuid.uuid4(),
        variants_dict[3][8].id,
        "https://img01.ztat.net/article/spp-media-p1/e3d46ff273a34a19a49e6443115b8140/91b9d8a903784ca5a703cb22801b1fe9.jpg?imwidth=1800",
        3
    ),
]

# %%
def generate_variant_images(file, variants_images):
    text = f'INSERT INTO variant_images(id, variant_id, url, is_main, position, created_at, updated_at)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    n = len(variants_images)
    for variant_image in variants_images[:n-1]:
        text = f"\t('{variant_image.id}', '{variant_image.variant_id}', '{variant_image.url}', {variant_image.is_main}, '{variant_image.position}', '{datetime.now()}', '{datetime.now()}'),\n"
        file.write(text)
    #

    variant_image = variants_images[-1]
    text = f"\t('{variant_image.id}', '{variant_image.variant_id}', '{variant_image.url}', {variant_image.is_main}, '{variant_image.position}', '{datetime.now()}', '{datetime.now()}');\n\n"
    file.write(text)
#

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
        generate_variant_images(file, variants_images)

# %%
class Property:
    def __init__(self, id, category_id, name, unit, data_type, has_default_options = "TRUE", role = "INFO"):
        self.id = id
        self.category_id = category_id
        self.name = name
        self.unit = unit
        self.data_type = data_type
        self.has_default_options = has_default_options
        self.role = role

# %%
properties_list = [
    Property(
        uuid.uuid4(),
        category_dict["Mobile Phones"],
        "Memory (RAM)",
        "NULL",
        "NUMBER",
        "TRUE",
    ),
    Property(
        uuid.uuid4(),
        category_dict["Mobile Phones"],
        "Device storage",
        "NULL",
        "NUMBER",
        "TRUE",
    ),
    Property(
        uuid.uuid4(),
        category_dict["Mobile Phones"],
        "Screen size range",
        "NULL",
        "TEXT",
        "FALSE",
    ),
    Property(
        uuid.uuid4(),
        category_dict["Clothes"],
        "Size",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),
    Property(
        uuid.uuid4(),
        category_dict["Clothes"],
        "Color",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # Washing machines

    # 5
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Brand",
        "NULL",
        "TEXT",
        "TRUE",
        "REQUIRED"
    ),
    # 6
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Model",
        "NULL",
        "TEXT",
        "FALSE",
        "REQUIRED"
    ),
    # 7
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Dominant Color",
        "NULL",
        "TEXT",
        "TRUE",
        "REQUIRED"
    ),
    # 8
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Drum Capacity",
        "kg",
        "TEXT",
        "TRUE",
        "REQUIRED"
    ),
    # 9
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Condition",
        "NULL",
        "TEXT",
        "TRUE",
        "INFO"
    ),
    # 10
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Dimensions",
        "W x D x H",
        "TEXT",
        "FALSE",
        "INFO"
    ),
    # 11
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Maximum Spin Speed",
        "rpm",
        "TEXT",
        "FALSE",
        "INFO"
    ),
    # 12
    Property(
        uuid.uuid4(),
        category_dict["Washing machines"],
        "Noise Level During Spinning",
        "dB",
        "TEXT",
        "FALSE",
        "INFO"
    ),

    # 13
    Property(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "Clothing brand",
        "NULL",
        "TEXT",
        "FALSE",
        "REQUIRED"
    ),

    # 14
    Property(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "Condition",
        "NULL",
        "TEXT",
        "TRUE",
        "REQUIRED"
    ),

    #15
    Property(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "Main material",
        "NULL",
        "TEXT",
        "FALSE",
        "REQUIRED"
    ),

    # 16
        Property(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "Size",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # 17
    Property(
        uuid.uuid4(),
        category_dict["T-shirts"],
        "Color",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # 18
        Property(
        uuid.uuid4(),
        category_dict["Jackets"],
        "Size",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # 19
    Property(
        uuid.uuid4(),
        category_dict["Jackets"],
        "Color",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # 20
        Property(
        uuid.uuid4(),
        category_dict["Sweatshirts"],
        "Size",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),

    # 21
    Property(
        uuid.uuid4(),
        category_dict["Sweatshirts"],
        "Color",
        "NULL",
        "TEXT",
        "TRUE",
        "SELECTABLE"
    ),
]

# %%
class VariantProperty:
    def __init__(self, id, variant_id, property_id, display_text, value_text = "NULL", value_decimal = "NULL", value_boolean = "NULL", value_date = "NULL"):
        self.id = id
        self.variant_id = variant_id
        self.property_id = property_id
        self.display_text = display_text
        self.value_text = value_text
        self.value_decimal = value_decimal
        self.value_boolean = value_boolean
        self.value_date = value_date

# %%
variant_properties_list = [
    
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[5].id,
        "Bosch"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[6].id,
        "WAN2415GPL"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[7].id,
        "White"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[8].id,
        "8"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[9].id,
        "New"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[10].id,
        "60 x 59 x 85"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[11].id,
        "1200"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[1][0].id,
        properties_list[12].id,
        "71"
    )
]

# %%
variant_properties_list.extend([
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[5].id,
        "Bosch"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[6].id,
        "WGG154ZSPL"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[7].id,
        "White"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[8].id,
        "9"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[9].id,
        "New"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[10].id,
        "59.8 x 58.8 x 84.5"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[11].id,
        "1400"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[12].id,
        "71"
    ),

    VariantProperty(
        uuid.uuid4(),
        variants_dict[2][0].id,
        properties_list[12].id,
        "71"
    ),
])

# %%
variant_properties_list.extend([
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[5].id,
        "Bosch"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[6].id,
        "WGB2440EPL"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[7].id,
        "White"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[8].id,
        "10"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[9].id,
        "New"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[10].id,
        "59.8 x 58.8 x 84.5"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[11].id,
        "1400"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[4][0].id,
        properties_list[12].id,
        "71"
    )
])

# %%
variant_properties_list.extend([
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[5].id,
        "Whirlpool"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[6].id,
        "AWG 1114SD/PRO"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[7].id,
        "Silver"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[8].id,
        "11"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[9].id,
        "New"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[10].id,
        "59.5 x 60 x 85"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[11].id,
        "1400"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[5][0].id,
        properties_list[12].id,
        "71"
    )
])

# %%
variant_properties_list.extend([
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[5].id,
        "Whirlpool"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[6].id,
        "FFB 9258 SV PL"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[7].id,
        "White"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[8].id,
        "9"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[9].id,
        "New"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[10].id,
        "59.8 x 58.8 x 84.5"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[11].id,
        "1200"
    ),
    VariantProperty(
        uuid.uuid4(),
        variants_dict[6][0].id,
        properties_list[12].id,
        "79"
    )
])

# %%
import math 

sizes = ["M", "L", "XL"]
colors = ["Red", "Black", "Blue"]

for idx, variant in enumerate(variants_dict[0]):

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[3].id,
        sizes[idx % len(sizes)]
    )
    variant_properties_list.append(variant_property)
    #

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[4].id,
        colors[idx // 3]
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[13].id,
        "U.S. Polo Assn."
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[14].id,
        "New"
    )
    variant_properties_list.append(variant_property)    

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[15].id,
        "Cotton"
    )
    variant_properties_list.append(variant_property)
#

for idx, variant in enumerate(variants_dict[3]):

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[3].id,
        sizes[idx % len(sizes)]
    )
    variant_properties_list.append(variant_property)
    #

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[4].id,
        colors[idx // 3]
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[13].id,
        "U.S. Polo Assn."
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[14].id,
        "New"
    )
    variant_properties_list.append(variant_property)    

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[15].id,
        "Cotton"
    )
    variant_properties_list.append(variant_property)    
#

# %%
for idx, variant in enumerate(variants_dict[7]):

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[3].id,
        sizes[idx % len(sizes)]
    )
    variant_properties_list.append(variant_property)
    #

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[4].id,
        colors[idx // 3]
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[13].id,
        "U.S. Polo Assn."
    )
    variant_properties_list.append(variant_property)

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[14].id,
        "New"
    )
    variant_properties_list.append(variant_property)    

    variant_property = VariantProperty(
        uuid.uuid4(),
        variant.id,
        properties_list[15].id,
        "Cotton"
    )
    variant_properties_list.append(variant_property)    
#

# %%
class DefaultPropertyOption:
    def __init__(self, id, property_id, display_text, value_text = "NULL", value_decimal = "NULL", value_boolean = "NULL", value_date = "NULL"):
        self.id = id
        self.property_id = property_id
        self.display_text = display_text
        self.value_text = value_text
        self.value_decimal = value_decimal
        self.value_boolean = value_boolean
        self.value_date = value_date

# %%
default_property_options_list = [
    
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[3].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[3].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[3].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[4].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[4].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[4].id,
        "Blue"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[5].id,
        "Bosch"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[5].id,
        "Siemens"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[5].id,
        "Whirlpool"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[5].id,
        "Amica"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[5].id,
        "Electrolux"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[7].id,
        "White"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[7].id,
        "Silver"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[7].id,
        "Black"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "6"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "7"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "8"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "9"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "10"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[8].id,
        "11"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[9].id,
        "New"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[9].id,
        "Used"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[14].id,
        "New"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[14].id,
        "Used"
    ),


    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[16].id,
        "Blue"
    ),


DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[17].id,
        "Blue"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[18].id,
        "Blue"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[19].id,
        "Blue"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[20].id,
        "Blue"
    ),

    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "M"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "L"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "XL"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "Red"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "Black"
    ),
    DefaultPropertyOption(
        uuid.uuid4(),
        properties_list[21].id,
        "Blue"
    ),
]

# %%
def generate_properties(file, properties_list):
    text = f'INSERT INTO properties(id, category_id, name, unit, data_type, has_default_options, role)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    n = len(properties_list)
    for property in properties_list[:n-1]:
        if property.unit == "NULL":
            text = f"\t('{property.id}', '{property.category_id}', '{property.name}', {property.unit}, '{property.data_type}', '{property.has_default_options}', '{property.role}'),\n"
        else:
            text = f"\t('{property.id}', '{property.category_id}', '{property.name}', '{property.unit}', '{property.data_type}', '{property.has_default_options}', '{property.role}'),\n"
        file.write(text)
    #

    property = properties_list[-1]

    if property.unit == "NULL":
        text = f"\t('{property.id}', '{property.category_id}', '{property.name}', {property.unit}, '{property.data_type}', '{property.has_default_options}', '{property.role}');\n\n"
    else:
        text = f"\t('{property.id}', '{property.category_id}', '{property.name}', '{property.unit}', '{property.data_type}', '{property.has_default_options}', '{property.role}');\n\n"

    file.write(text)
#

# %%
def generate_default_property_options(file, default_property_options_list):
    text = f'INSERT INTO default_property_options(id, property_id, value_text, value_decimal, value_boolean, value_date, display_text)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    n = len(default_property_options_list)
    for dpo in default_property_options_list[:n-1]:
        text = f"\t('{dpo.id}', '{dpo.property_id}', {dpo.value_text}, {dpo.value_decimal}, {dpo.value_boolean}, {dpo.value_date}, '{dpo.display_text}'),\n"
        file.write(text)
    #

    dpo = default_property_options_list[-1]
    text = f"\t('{dpo.id}', '{dpo.property_id}', {dpo.value_text}, {dpo.value_decimal}, {dpo.value_boolean}, {dpo.value_date}, '{dpo.display_text}');\n\n"
    file.write(text)
#

# %%
def generate_variant_properties(file, variant_properties_list):
    text = f'INSERT INTO variant_properties(id, variant_id, property_id, value_text, value_decimal, value_boolean, value_date, display_text)\n'
    file.write(text)
    
    text = f'VALUES\n'
    file.write(text)

    n = len(variant_properties_list)
    for vp in variant_properties_list[:n-1]:
        text = f"\t('{vp.id}', '{vp.variant_id}', '{vp.property_id}', '{vp.display_text}', {vp.value_decimal}, {vp.value_boolean}, {vp.value_date}, '{vp.display_text}'),\n"
        file.write(text)
    #

    vp = variant_properties_list[-1]
    text = f"\t('{vp.id}', '{vp.variant_id}', '{vp.property_id}', '{vp.display_text}', {vp.value_decimal}, {vp.value_boolean}, {vp.value_date}, '{vp.display_text}');\n\n"
    file.write(text)
#

# %%
with open("sample_data.sql", "a", encoding="utf-8") as file:
        generate_properties(file, properties_list)
        generate_default_property_options(file, default_property_options_list)
        generate_variant_properties(file, variant_properties_list)
